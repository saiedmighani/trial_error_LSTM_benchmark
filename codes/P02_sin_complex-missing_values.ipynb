# %% [markdown]
# Importing the required libraries:

# %%
import numpy as np
import pandas as pd
from math import sqrt

import pickle
import os
import datetime
import seaborn as sns
import matplotlib.pyplot as plt

## for machine learning

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_squared_error

from tensorflow import keras

from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Masking

# %% [markdown]
# ## Preparing the sine wave function

# %%
x_axis = np.arange(-50*np.pi, 50*np.pi, 0.1)
y_1_axis = np.sin(x_axis)
y_2_axis = np.sin(2*x_axis)
y_3_axis = np.sin(3*x_axis)
y_axis = y_1_axis + y_2_axis + y_3_axis

df = pd.DataFrame({"x_axis": x_axis, "y_axis":y_axis})

df.head()
# Out:
#        x_axis        y_axis
# 0 -157.079633  2.252855e-14
# 1 -156.979633  5.940230e-01
# 2 -156.879633  1.152730e+00
# 3 -156.779633  1.643490e+00
# 4 -156.679633  2.038814e+00

# %%
sns.lineplot(data=df, x="x_axis", y="y_axis");

# %%
# Adding NaN values to the dataframe
import random
col = 1

for row in random.sample(range(len(df)), int(round(.1*len(df)))):
    df.iat[row, col] = np.nan


df.head(10)
# Out:
#        x_axis        y_axis
# 0 -157.079633  2.252855e-14
# 1 -156.979633  5.940230e-01
# 2 -156.879633  1.152730e+00
# 3 -156.779633  1.643490e+00
# 4 -156.679633  2.038814e+00
# 5 -156.579633           NaN
# 6 -156.479633  2.470529e+00
# 7 -156.379633  2.492877e+00
# 8 -156.279633  2.392393e+00
# 9 -156.179633           NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3142 entries, 0 to 3141
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x_axis  3142 non-null   float64
#  1   y_axis  2828 non-null   float64
# dtypes: float64(2)
# memory usage: 49.2 KB

# %%
df_eq_model = df.copy()

train_size = int(len(df_eq_model)* 0.9)
test_size = len(df_eq_model) - train_size
train, test = df_eq_model.iloc[0:train_size], df_eq_model.iloc[train_size:len(df_eq_model)]

print(train.shape, test.shape)
# Out:
# (2827, 2) (315, 2)

# %%
train.head(2)
# Out:
#        x_axis        y_axis
# 0 -157.079633  2.252855e-14
# 1 -156.979633  5.940230e-01

# %%
test.head(2)
# Out:
#           x_axis    y_axis
# 2827  125.620367       NaN
# 2828  125.720367  0.338877

# %%
from sklearn.preprocessing import RobustScaler

f_columns = ["x_axis"]

f_transformer = RobustScaler()
y_transformer = RobustScaler()

f_transformer = f_transformer.fit(train[f_columns].to_numpy())
y_transformer = y_transformer.fit(train[["y_axis"]])

# %%
f_transformer.get_params()
# Out:
# {'copy': True,
#  'quantile_range': (25.0, 75.0),
#  'with_centering': True,
#  'with_scaling': True}

# %%
train.loc[:,f_columns] = f_transformer.transform(train[f_columns].to_numpy())
train["y_axis"] = y_transformer.transform(train[["y_axis"]])

test.loc[:,f_columns] = f_transformer.transform(test[f_columns].to_numpy())
test["y_axis"] = y_transformer.transform(test[["y_axis"]])
# Out:
# /Users/smighani/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# /Users/smighani/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/smighani/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/smighani/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# /Users/smighani/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/smighani/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %% [markdown]
# ### Preparing the data for LSTM

# %%
def create_dataset(X, y, time_steps = 1):
    Xs, ys = [], []
    for i in range(len(X)- time_steps):
        v = X.iloc[i: (i + time_steps)].to_numpy()
        Xs.append(v)
        ys.append(y.iloc[i+time_steps])
    return np.array(Xs), np.array(ys)

# %%
TIME_STEPS = 60

X_train, y_train = create_dataset(train, train["y_axis"], time_steps = TIME_STEPS)

X_test, y_test = create_dataset(test, test["y_axis"], time_steps= TIME_STEPS)

# %%
print(X_train.shape, y_train.shape)

print(X_test.shape, y_test.shape)
# Out:
# (2767, 60, 2) (2767,)
# (255, 60, 2) (255,)

# %%
X_train[0][0]
# Out:
# array([-1.        , -0.00681541])

# %% [markdown]
# ## Model Architecture

# %%
model = keras.Sequential()
# Adding bi-directional layer
model.add(
    keras.layers.Bidirectional(
        keras.layers.LSTM(
            units=64,
            input_shape = (X_train.shape[1], X_train.shape[2])
        )
    )
)
# Adding dropout layer to regularize complexities 
model.add(keras.layers.Dropout(rate = 0.2))
# Add output layer
model.add(keras.layers.Dense(units = 1))

# %%
# Compiling the model
model.compile(loss = "mean_squared_error", optimizer = "adam")

# %%
history = model.fit(
    X_train, y_train,
    epochs = 20,
    batch_size = 32,
    validation_split = 0.33, 
    shuffle = False # As it is time-series
)
# Out:
# Epoch 1/20
# 58/58 [==============================] - 2s 39ms/step - loss: nan - val_loss: nan
# Epoch 2/20
# 58/58 [==============================] - 1s 21ms/step - loss: nan - val_loss: nan
# Epoch 3/20
# 58/58 [==============================] - 1s 20ms/step - loss: nan - val_loss: nan
# Epoch 4/20
# 58/58 [==============================] - 1s 20ms/step - loss: nan - val_loss: nan
# Epoch 5/20
# 58/58 [==============================] - 1s 25ms/step - loss: nan - val_loss: nan
# Epoch 6/20
# 58/58 [==============================] - 1s 24ms/step - loss: nan - val_loss: nan
# Epoch 7/20
# 58/58 [==============================] - 1s 24ms/step - loss: nan - val_loss: nan
# Epoch 8/20
# 58/58 [==============================] - 1s 20ms/step - loss: nan - val_loss: nan
# Epoch 9/20
# 58/58 [==============================] - 1s 21ms/step - loss: nan - val_loss: nan
# Epoch 10/20
# 58/58 [==============================] - 1s 21ms/step - loss: nan - val_loss: nan
# Epoch 11/20
# 58/58 [==============================] - 1s 21ms/step - loss: nan - val_loss: nan
# Epoch 12/20
# 58/58 [==============================] - 1s 22ms/step - loss: nan - val_loss: nan
# Epoch 13/20
# 58/58 [==============================] - 1s 22ms/step - loss: nan - val_loss: nan
# Epoch 14/20
# 58/58 [==============================] - 1s 21ms/step - loss: nan - val_loss: nan
# Epoch 15/20
# 58/58 [==============================] - 1s 21ms/step - loss: nan - val_loss: nan
# Epoch 16/20
# 58/58 [==============================] - 1s 18ms/step - loss: nan - val_loss: nan
# Epoch 17/20
# 58/58 [==============================] - 1s 19ms/step - loss: nan - val_loss: nan
# Epoch 18/20
# 58/58 [==============================] - 1s 26ms/step - loss: nan - val_loss: nan
# Epoch 19/20
# 58/58 [==============================] - 1s 18ms/step - loss: nan - val_loss: nan
# Epoch 20/20
# 58/58 [==============================] - 2s 28ms/step - loss: nan - val_loss: nan

# %%
# %config InlineBackend.figure_format = 'retina'


plt.figure(figsize = (9, 6))


# plt.figure(figsize = (14,10))
plt.plot(history.history["loss"], color='black', marker = '.', linewidth = 2, label = "train")
plt.plot(history.history["val_loss"], color='red', marker = '.', linewidth = 2, label = "validation")
plt.legend(fontsize = 14)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.xticks(np.arange(0, 20+1, 4))
plt.xlim(0, 20)
# plt.ylim(0, 3)
plt.xlabel("Epochs", fontsize = 14)
plt.ylabel("Loss", fontsize = 14)

plt.title("Loss function (mean square error)", fontsize = 16);
plt.savefig('../plots/fig_1_medium_a.png')

# %%
y_pred = model.predict(X_test)

# %%
y_train_inv = y_transformer.inverse_transform(y_train.reshape(1,-1))
y_test_inv = y_transformer.inverse_transform(y_test.reshape(1,-1))
y_pred_inv = y_transformer.inverse_transform(y_pred)

# %%
# %config InlineBackend.figure_format = 'retina'


plt.figure(figsize = (9, 6))


# plt.figure(figsize = (14,10))
plt.plot(y_test_inv.flatten(), color='blue', marker = '.', linewidth = 2, label = "True")
plt.plot(y_pred_inv.flatten(), color='red', marker = '.', linewidth = 2, label = "Predicted")

plt.legend(fontsize = 14)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
# plt.xlim(0, 250)
# plt.ylim(0, 3)
plt.xlabel("x axis", fontsize = 14)
plt.ylabel("y axis", fontsize = 14);
plt.title("LSTM predictions", fontsize = 16);


plt.savefig('../plots/fig_1_medium_b.png')

# %% [markdown]
# # Refining the model by adding mask

# %% [markdown]
# ## Model Architecture

# %%
## Filling NA with -1
df.fillna(-1.0, inplace=True)

df.describe().T
# Out:
#          count      mean        std         min        25%       50%  \
# x_axis  3142.0 -0.029633  90.716160 -157.079633 -78.554633 -0.029633
# y_axis  3142.0 -0.107047   1.203782   -2.499602  -1.000000 -0.112561
#
#               75%         max
# x_axis  78.495367  157.020367
# y_axis   0.497743    2.499608

# %%
df_eq_model = df.copy()

train_size = int(len(df_eq_model)* 0.9)
test_size = len(df_eq_model) - train_size
train, test = df_eq_model.iloc[0:train_size], df_eq_model.iloc[train_size:len(df_eq_model)]

print(train.shape, test.shape)
# Out:
# (2827, 2) (315, 2)

# %%
train.head(5)
# Out:
#        x_axis        y_axis
# 0 -157.079633  2.252855e-14
# 1 -156.979633  5.940230e-01
# 2 -156.879633  1.152730e+00
# 3 -156.779633  1.643490e+00
# 4 -156.679633  2.038814e+00

# %%
test.head(5)
# Out:
#           x_axis    y_axis
# 2827  125.620367 -1.000000
# 2828  125.720367  0.338877
# 2829  125.820367  0.917114
# 2830  125.920367  1.441050
# 2831  126.020367  1.880690

# %%
from sklearn.preprocessing import RobustScaler

f_columns = ["x_axis"]

f_transformer = RobustScaler()
y_transformer = RobustScaler()

f_transformer = f_transformer.fit(train[f_columns].to_numpy())
y_transformer = y_transformer.fit(train[["y_axis"]])

# %%
f_transformer.get_params()
# Out:
# {'copy': True,
#  'quantile_range': (25.0, 75.0),
#  'with_centering': True,
#  'with_scaling': True}

# %%
train.loc[:,f_columns] = f_transformer.transform(train[f_columns].to_numpy())
train["y_axis"] = y_transformer.transform(train[["y_axis"]])

test.loc[:,f_columns] = f_transformer.transform(test[f_columns].to_numpy())
test["y_axis"] = y_transformer.transform(test[["y_axis"]])
# Out:
# /Users/smighani/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# /Users/smighani/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/smighani/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/smighani/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# /Users/smighani/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/smighani/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %% [markdown]
# ### Preparing the data for LSTM

# %%
def create_dataset(X, y, time_steps = 1):
    Xs, ys = [], []
    for i in range(len(X)- time_steps):
        v = X.iloc[i: (i + time_steps)].to_numpy()
        Xs.append(v)
        ys.append(y.iloc[i+time_steps])
    return np.array(Xs), np.array(ys)

# %%
TIME_STEPS = 60

X_train, y_train = create_dataset(train, train["y_axis"], time_steps = TIME_STEPS)

X_test, y_test = create_dataset(test, test["y_axis"], time_steps= TIME_STEPS)

# %%
print(X_train.shape, y_train.shape)

print(X_test.shape, y_test.shape)
# Out:
# (2767, 60, 2) (2767,)
# (255, 60, 2) (255,)

# %%
X_train[0][0]
# Out:
# array([-1.        ,  0.07371239])

# %%
model = keras.Sequential()
# Adding mask layer for NaN values
model.add(Masking(mask_value = -1.0,
                                  input_shape=(X_train.shape[1], X_train.shape[2])
                              )
         )
# Adding mask layer for NaN values


# Adding bi-directional layer
model.add(
    keras.layers.Bidirectional(
        keras.layers.LSTM(
            units=64,
            input_shape = (X_train.shape[1], X_train.shape[2])
        )
    )
)
# Adding dropout layer to regularize complexities 
model.add(keras.layers.Dropout(rate = 0.2))
# Add output layer
model.add(keras.layers.Dense(units = 1))

# %%
# Compiling the model
model.compile(loss = "mean_squared_error", optimizer = "adam")

# %%
history = model.fit(
    X_train, y_train,
    epochs = 20,
    batch_size = 32,
    validation_split = 0.33, 
    shuffle = False # As it is time-series
)
# Out:
# Epoch 1/20
# 58/58 [==============================] - 5s 79ms/step - loss: 0.3200 - val_loss: 0.1420
# Epoch 2/20
# 58/58 [==============================] - 2s 29ms/step - loss: 0.1430 - val_loss: 0.1226
# Epoch 3/20
# 58/58 [==============================] - 2s 31ms/step - loss: 0.1289 - val_loss: 0.1142
# Epoch 4/20
# 58/58 [==============================] - 2s 29ms/step - loss: 0.1251 - val_loss: 0.1045
# Epoch 5/20
# 58/58 [==============================] - 2s 27ms/step - loss: 0.1217 - val_loss: 0.1083
# Epoch 6/20
# 58/58 [==============================] - 2s 34ms/step - loss: 0.1225 - val_loss: 0.1104
# Epoch 7/20
# 58/58 [==============================] - 2s 38ms/step - loss: 0.1215 - val_loss: 0.1153
# Epoch 8/20
# 58/58 [==============================] - 2s 29ms/step - loss: 0.1201 - val_loss: 0.1158
# Epoch 9/20
# 58/58 [==============================] - 2s 29ms/step - loss: 0.1163 - val_loss: 0.1032
# Epoch 10/20
# 58/58 [==============================] - 2s 31ms/step - loss: 0.1202 - val_loss: 0.1083
# Epoch 11/20
# 58/58 [==============================] - 2s 28ms/step - loss: 0.1165 - val_loss: 0.1036
# Epoch 12/20
# 58/58 [==============================] - 2s 39ms/step - loss: 0.1164 - val_loss: 0.1057
# Epoch 13/20
# 58/58 [==============================] - 2s 34ms/step - loss: 0.1217 - val_loss: 0.1021
# Epoch 14/20
# 58/58 [==============================] - 2s 30ms/step - loss: 0.1167 - val_loss: 0.1060
# Epoch 15/20
# 58/58 [==============================] - 2s 31ms/step - loss: 0.1155 - val_loss: 0.1199
# Epoch 16/20
# 58/58 [==============================] - 2s 32ms/step - loss: 0.1165 - val_loss: 0.1283
# Epoch 17/20
# 58/58 [==============================] - 2s 31ms/step - loss: 0.1165 - val_loss: 0.1281
# Epoch 18/20
# 58/58 [==============================] - 2s 38ms/step - loss: 0.1168 - val_loss: 0.1556
# Epoch 19/20
# 58/58 [==============================] - 2s 35ms/step - loss: 0.1175 - val_loss: 0.1941
# Epoch 20/20
# 58/58 [==============================] - 2s 32ms/step - loss: 0.1172 - val_loss: 0.1786

# %%
# %config InlineBackend.figure_format = 'retina'


plt.figure(figsize = (9, 6))


# plt.figure(figsize = (14,10))
plt.plot(history.history["loss"], color='black', marker = '.', linewidth = 2, label = "train")
plt.plot(history.history["val_loss"], color='red', marker = '.', linewidth = 2, label = "validation")
plt.legend(fontsize = 14)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.xticks(np.arange(0, 20+1, 4))
plt.xlim(0, 20)
# plt.ylim(0, 3)
plt.xlabel("Epochs", fontsize = 14)
plt.ylabel("Loss", fontsize = 14)

plt.title("Loss function (mean square error)", fontsize = 16);
plt.savefig('../plots/fig_1_medium_a.png')

# %%
y_pred = model.predict(X_test)

# %%
y_train_inv = y_transformer.inverse_transform(y_train.reshape(1,-1))
y_test_inv = y_transformer.inverse_transform(y_test.reshape(1,-1))
y_pred_inv = y_transformer.inverse_transform(y_pred)

# %%
# %config InlineBackend.figure_format = 'retina'


plt.figure(figsize = (9, 6))


# plt.figure(figsize = (14,10))
plt.plot(y_test_inv.flatten(), color='blue', marker = '.', linewidth = 2, label = "True")
plt.plot(y_pred_inv.flatten(), color='red', marker = '.', linewidth = 2, label = "Predicted")

plt.legend(fontsize = 14)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
# plt.xlim(0, 250)
# plt.ylim(0, 3)
plt.xlabel("x axis", fontsize = 14)
plt.ylabel("y axis", fontsize = 14);
plt.title("LSTM predictions", fontsize = 16);


plt.savefig('../plots/fig_1_medium_b.png')

# %% [markdown]
# ## What happens if I didnt add the mask layer for LSTM architecture ?

# %%
model = keras.Sequential()

# Adding bi-directional layer
model.add(
    keras.layers.Bidirectional(
        keras.layers.LSTM(
            units=64,
            input_shape = (X_train.shape[1], X_train.shape[2])
        )
    )
)
# Adding dropout layer to regularize complexities 
model.add(keras.layers.Dropout(rate = 0.2))
# Add output layer
model.add(keras.layers.Dense(units = 1))

# %%
# Compiling the model
model.compile(loss = "mean_squared_error", optimizer = "adam")

# %%
history = model.fit(
    X_train, y_train,
    epochs = 20,
    batch_size = 32,
    validation_split = 0.33, 
    shuffle = False # As it is time-series
)
# Out:
# Epoch 1/20
# 58/58 [==============================] - 3s 51ms/step - loss: 0.4214 - val_loss: 0.1341
# Epoch 2/20
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1517 - val_loss: 0.1258
# Epoch 3/20
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1333 - val_loss: 0.1301
# Epoch 4/20
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1267 - val_loss: 0.1184
# Epoch 5/20
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1236 - val_loss: 0.1252
# Epoch 6/20
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1255 - val_loss: 0.1164
# Epoch 7/20
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1192 - val_loss: 0.1104
# Epoch 8/20
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1206 - val_loss: 0.1049
# Epoch 9/20
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1215 - val_loss: 0.1123
# Epoch 10/20
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1186 - val_loss: 0.1093
# Epoch 11/20
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1181 - val_loss: 0.1090
# Epoch 12/20
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1184 - val_loss: 0.1117
# Epoch 13/20
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1176 - val_loss: 0.1092
# Epoch 14/20
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1172 - val_loss: 0.1044
# Epoch 15/20
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1179 - val_loss: 0.1153
# Epoch 16/20
# 58/58 [==============================] - 1s 19ms/step - loss: 0.1169 - val_loss: 0.1119
# Epoch 17/20
# 58/58 [==============================] - 1s 19ms/step - loss: 0.1171 - val_loss: 0.1143
# Epoch 18/20
# 58/58 [==============================] - 2s 27ms/step - loss: 0.1171 - val_loss: 0.1174
# Epoch 19/20
# 58/58 [==============================] - 2s 27ms/step - loss: 0.1169 - val_loss: 0.1264
# Epoch 20/20
# 58/58 [==============================] - 2s 27ms/step - loss: 0.1164 - val_loss: 0.1386

# %%
# %config InlineBackend.figure_format = 'retina'


plt.figure(figsize = (9, 6))


# plt.figure(figsize = (14,10))
plt.plot(history.history["loss"], color='black', marker = '.', linewidth = 2, label = "train")
plt.plot(history.history["val_loss"], color='red', marker = '.', linewidth = 2, label = "validation")
plt.legend(fontsize = 14)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.xticks(np.arange(0, 20+1, 4))
plt.xlim(0, 20)
# plt.ylim(0, 3)
plt.xlabel("Epochs", fontsize = 14)
plt.ylabel("Loss", fontsize = 14)

plt.title("Loss function (mean square error)", fontsize = 16);
plt.savefig('../plots/fig_1_medium_a.png')

# %%
y_pred = model.predict(X_test)

# %%
y_train_inv = y_transformer.inverse_transform(y_train.reshape(1,-1))
y_test_inv = y_transformer.inverse_transform(y_test.reshape(1,-1))
y_pred_inv = y_transformer.inverse_transform(y_pred)

# %%
# %config InlineBackend.figure_format = 'retina'


plt.figure(figsize = (9, 6))


# plt.figure(figsize = (14,10))
plt.plot(y_test_inv.flatten(), color='blue', marker = '.', linewidth = 2, label = "True")
plt.plot(y_pred_inv.flatten(), color='red', marker = '.', linewidth = 2, label = "Predicted")

plt.legend(fontsize = 14)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
# plt.xlim(0, 250)
# plt.ylim(0, 3)
plt.xlabel("x axis", fontsize = 14)
plt.ylabel("y axis", fontsize = 14);
plt.title("LSTM predictions", fontsize = 16);


plt.savefig('../plots/fig_1_medium_b.png')

# %%
print("Hello World!")
# Out:
# Hello World!
